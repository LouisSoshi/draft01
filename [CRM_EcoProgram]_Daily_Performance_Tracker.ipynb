# %% [markdown]
# <a href="https://colab.research.google.com/github/LouisSoshi/draft01/blob/main/%5BCRM_EcoProgram%5D_Daily_Performance_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import gspread
from google.auth import default
#autenticating to google
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

import pandas as pd
#defining my worksheet
sh2 = gc.open('CRM_PMO_PNL').worksheet("PMO_CAMPAIGN_full_metrics_pnl")
output2 = gc.open('[CRM-EcoProgram] Daily Performance Tracker').worksheet("full_metrics_pnl")

sh3 = gc.open('CRM_PMO_PNL').worksheet("PMO_GROUP_USER_full_metrics_pnl")
output3 = gc.open('[CRM-EcoProgram] Daily Performance Tracker').worksheet("group_user")

# %%
sheet2 = sh2.get_all_values()
df2 = pd.DataFrame(sheet2)
df2.columns = df2.iloc[0]
df2 = df2.iloc[1:,]
df2 = df2.assign(Index=range(len(df2))).set_index('Index')
list(df2.columns.values)
# Out:
# ['group_user',
#  'project',
#  'campaign_name',
#  'entry_date',
#  'is_auto',
#  'control_fraction',
#  'contact_type',
#  'total_base',
#  'base_fraction',
#  'grass_date',
#  'order_type',
#  'order_total',
#  'order_pg',
#  'order_dp',
#  'order_spf',
#  'order_total_any_voucher',
#  'order_pg_any_voucher',
#  'order_dp_any_voucher',
#  'order_spf_any_voucher',
#  'order_total_any_fsv_voucher',
#  'order_total_campaign_voucher',
#  'order_pg_campaign_voucher',
#  'order_pg_campaign_fsv_voucher',
#  'order_pg_campaign_nonfsv_voucher',
#  'order_dp_campaign_voucher',
#  'order_spf_campaign_voucher',
#  'checkout_total',
#  'checkout_pg',
#  'checkout_dp',
#  'checkout_spf',
#  'checkout_total_any_voucher',
#  'checkout_pg_any_voucher',
#  'checkout_dp_any_voucher',
#  'checkout_spf_any_voucher',
#  'checkout_total_any_fsv_voucher',
#  'checkout_total_campaign_voucher',
#  'checkout_pg_campaign_voucher',
#  'checkout_pg_campaign_fsv_voucher',
# ...

# %%
cols = [
'order_total',
 'order_pg',
 'order_dp',
 'order_spf',
 'order_total_any_voucher',
 'order_pg_any_voucher',
 'order_dp_any_voucher',
 'order_spf_any_voucher',
 'order_total_any_fsv_voucher',
 'order_total_campaign_voucher',
 'order_pg_campaign_voucher',
 'order_pg_campaign_fsv_voucher',
 'order_pg_campaign_nonfsv_voucher',
 'order_dp_campaign_voucher',
 'order_spf_campaign_voucher',
 'checkout_total',
 'checkout_pg',
 'checkout_dp',
 'checkout_spf',
 'checkout_total_any_voucher',
 'checkout_pg_any_voucher',
 'checkout_dp_any_voucher',
 'checkout_spf_any_voucher',
 'checkout_total_any_fsv_voucher',
 'checkout_total_campaign_voucher',
 'checkout_pg_campaign_voucher',
 'checkout_pg_campaign_fsv_voucher',
 'checkout_pg_campaign_nonfsv_voucher',
 'checkout_dp_campaign_voucher',
 'checkout_spf_campaign_voucher',
 'gmv_usd_total',
 'gmv_usd_pg',
 'gmv_usd_dp',
 'gmv_usd_spf',
 'gmv_usd_total_any_voucher',
 'gmv_usd_pg_any_voucher',
 'gmv_usd_dp_any_voucher',
 'gmv_usd_spf_any_voucher',
 'gmv_usd_total_any_fsv_voucher',
 'gmv_usd_total_campaign_voucher',
 'gmv_usd_pg_campaign_voucher',
 'gmv_usd_pg_campaign_fsv_voucher',
 'gmv_usd_pg_campaign_nonfsv_voucher',
 'gmv_usd_dp_campaign_voucher',
 'gmv_usd_spf_campaign_voucher',
 'buyer_total',
 'buyer_pg',
 'buyer_dp',
 'buyer_spf',
 'buyer_dp_spf',
 'buyer_total_any_voucher',
 'buyer_pg_any_voucher',
 'buyer_dp_any_voucher',
 'buyer_spf_any_voucher',
 'buyer_dp_spf_any_voucher',
 'buyer_total_any_fsv_voucher',
 'buyer_total_campaign_voucher',
 'buyer_pg_campaign_voucher',
 'buyer_pg_campaign_fsv_voucher',
 'buyer_pg_campaign_nonfsv_voucher',
 'buyer_dp_campaign_voucher',
 'buyer_spf_campaign_voucher',
 'buyer_dp_spf_campaign_voucher',
 'cost_usd_total',
 'cost_usd_pg',
 'cost_usd_dp',
 'cost_usd_spf',
 'cost_usd_total_fsv_voucher',
 'cost_usd_total_nonfsv_voucher',
 'cost_usd_pg_nonfsv_voucher',
 'cost_usd_dp_voucher',
 'cost_usd_spf_voucher',
 'cost_usd_total_campaign_fsv_voucher',
 'cost_usd_pg_campaign_nonfsv_voucher',
 'cost_usd_dp_campaign_voucher',
 'cost_usd_spf_campaign_voucher',
 'rev_pg_direct_revenue_usd',
 'rev_pg_direct_revenue_usd_campaign_voucher',
 'rev_pg_direct_revenue_usd_campaign_fsv_voucher',
 'rev_pg_direct_revenue_usd_campaign_nonfsv_voucher',
 'rev_paid_ads_by_user',
 'prm_usd_pg',
 'prm_usd_pg_campaign_voucher',
 'prm_usd_pg_campaign_fsv_voucher',
 'prm_usd_pg_campaign_nonfsv_voucher',
 'rev_marketing_package',
 'rev_marketing_package_campaign_voucher',
 'transaction_fee_usd',
 'transaction_fee_usd_campaign_voucher',
 'spx_margin_usd',
 'spx_margin_usd_campaign_voucher',
 'number_login',
 'users_login',
 'fss_commission_usd',
 'fss_commission_usd_campaign_fsv_voucher',
 'rev_handling_fee_usd',
 'rev_commission_fee_usd',
 'rev_fss_usd',
 'rev_fss_plus_usd',
 'rev_ccb_usd',
 'rev_paid_ads_usd',
 'rev_handling_fee_usd_campaign_voucher',
 'rev_commission_fee_usd_campaign_voucher',
 'rev_fss_usd_campaign_voucher',
 'rev_fss_plus_usd_campaign_voucher',
 'rev_ccb_usd_campaign_voucher',
 'rev_paid_ads_usd_campaign_voucher',
 'logistics_cost_usd',
 'pv_voucher_rebate_usd',
 'sv_voucher_rebate_usd',
 'item_rebate_usd',
 'logistics_cost_usd_campaign_voucher',
 'pv_voucher_rebate_usd_campaign_voucher',
 'sv_voucher_rebate_usd_campaign_voucher',
 'item_rebate_usd_campaign_voucher',
 'prm_usd_pnl',
 'prm_usd_pnl_campaign_voucher',
 'total_rev_usd',
 'total_rev_usd_campaign_voucher',
]
df2[cols] = df2[cols].apply(pd.to_numeric, errors='coerce', axis=1)
df2['pc1_usd_pg'] = df2['rev_paid_ads_usd'] + df2['rev_pg_direct_revenue_usd'] + df2['rev_marketing_package'] - df2['cost_usd_pg']
df2['pc2_usd_pg'] = df2['pc1_usd_pg'] - df2['transaction_fee_usd']
df2['pc1_usd_pmo'] = df2['rev_pg_direct_revenue_usd_campaign_voucher'] + df2['rev_paid_ads_usd_campaign_voucher'] + df2['rev_marketing_package_campaign_voucher']- df2['prm_usd_pg_campaign_voucher']
df2['pc2_usd_pmo'] = df2['pc1_usd_pmo'] - df2['transaction_fee_usd_campaign_voucher']

options2 = ['mall', 'platform','spp'] 
df_rs2 = df2[df2['project'].isin(options2)] 
df_rs2 = df_rs2[1:6000]
import gspread_dataframe as gd
gd.set_with_dataframe(output2, df_rs2)
# Out:
# <ipython-input-3-afa92e8de052>:123: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2['pc1_usd_pg'] = df2['rev_paid_ads_usd'] + df2['rev_pg_direct_revenue_usd'] + df2['rev_marketing_package'] - df2['cost_usd_pg']
# <ipython-input-3-afa92e8de052>:124: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2['pc2_usd_pg'] = df2['pc1_usd_pg'] - df2['transaction_fee_usd']
# ...

# %%
sheet3 = sh3.get_all_values()
df3 = pd.DataFrame(sheet3)
df3.columns = df3.iloc[0]
df3 = df3.iloc[1:,]
df3 = df3.assign(Index=range(len(df3))).set_index('Index')
cols = [
'order_total',
 'order_pg',
 'order_dp',
 'order_spf',
 'order_total_any_voucher',
 'order_pg_any_voucher',
 'order_dp_any_voucher',
 'order_spf_any_voucher',
 'order_total_any_fsv_voucher',
 'order_total_campaign_voucher',
 'order_pg_campaign_voucher',
 'order_pg_campaign_fsv_voucher',
 'order_pg_campaign_nonfsv_voucher',
 'order_dp_campaign_voucher',
 'order_spf_campaign_voucher',
 'checkout_total',
 'checkout_pg',
 'checkout_dp',
 'checkout_spf',
 'checkout_total_any_voucher',
 'checkout_pg_any_voucher',
 'checkout_dp_any_voucher',
 'checkout_spf_any_voucher',
 'checkout_total_any_fsv_voucher',
 'checkout_total_campaign_voucher',
 'checkout_pg_campaign_voucher',
 'checkout_pg_campaign_fsv_voucher',
 'checkout_pg_campaign_nonfsv_voucher',
 'checkout_dp_campaign_voucher',
 'checkout_spf_campaign_voucher',
 'gmv_usd_total',
 'gmv_usd_pg',
 'gmv_usd_dp',
 'gmv_usd_spf',
 'gmv_usd_total_any_voucher',
 'gmv_usd_pg_any_voucher',
 'gmv_usd_dp_any_voucher',
 'gmv_usd_spf_any_voucher',
 'gmv_usd_total_any_fsv_voucher',
 'gmv_usd_total_campaign_voucher',
 'gmv_usd_pg_campaign_voucher',
 'gmv_usd_pg_campaign_fsv_voucher',
 'gmv_usd_pg_campaign_nonfsv_voucher',
 'gmv_usd_dp_campaign_voucher',
 'gmv_usd_spf_campaign_voucher',
 'buyer_total',
 'buyer_pg',
 'buyer_dp',
 'buyer_spf',
 'buyer_dp_spf',
 'buyer_total_any_voucher',
 'buyer_pg_any_voucher',
 'buyer_dp_any_voucher',
 'buyer_spf_any_voucher',
 'buyer_dp_spf_any_voucher',
 'buyer_total_any_fsv_voucher',
 'buyer_total_campaign_voucher',
 'buyer_pg_campaign_voucher',
 'buyer_pg_campaign_fsv_voucher',
 'buyer_pg_campaign_nonfsv_voucher',
 'buyer_dp_campaign_voucher',
 'buyer_spf_campaign_voucher',
 'buyer_dp_spf_campaign_voucher',
 'cost_usd_total',
 'cost_usd_pg',
 'cost_usd_dp',
 'cost_usd_spf',
 'cost_usd_total_fsv_voucher',
 'cost_usd_total_nonfsv_voucher',
 'cost_usd_pg_nonfsv_voucher',
 'cost_usd_dp_voucher',
 'cost_usd_spf_voucher',
 'cost_usd_total_campaign_fsv_voucher',
 'cost_usd_pg_campaign_nonfsv_voucher',
 'cost_usd_dp_campaign_voucher',
 'cost_usd_spf_campaign_voucher',
 'rev_pg_direct_revenue_usd',
 'rev_pg_direct_revenue_usd_campaign_voucher',
 'rev_pg_direct_revenue_usd_campaign_fsv_voucher',
 'rev_pg_direct_revenue_usd_campaign_nonfsv_voucher',
 'rev_paid_ads_by_user',
 'prm_usd_pg',
 'prm_usd_pg_campaign_voucher',
 'prm_usd_pg_campaign_fsv_voucher',
 'prm_usd_pg_campaign_nonfsv_voucher',
 'rev_marketing_package',
 'rev_marketing_package_campaign_voucher',
 'transaction_fee_usd',
 'transaction_fee_usd_campaign_voucher',
 'spx_margin_usd',
 'spx_margin_usd_campaign_voucher',
 'number_login',
 'users_login',
 'fss_commission_usd',
 'fss_commission_usd_campaign_fsv_voucher',
 'rev_handling_fee_usd',
 'rev_commission_fee_usd',
 'rev_fss_usd',
 'rev_fss_plus_usd',
 'rev_ccb_usd',
 'rev_paid_ads_usd',
 'rev_handling_fee_usd_campaign_voucher',
 'rev_commission_fee_usd_campaign_voucher',
 'rev_fss_usd_campaign_voucher',
 'rev_fss_plus_usd_campaign_voucher',
 'rev_ccb_usd_campaign_voucher',
 'rev_paid_ads_usd_campaign_voucher',
 'logistics_cost_usd',
 'pv_voucher_rebate_usd',
 'sv_voucher_rebate_usd',
 'item_rebate_usd',
 'logistics_cost_usd_campaign_voucher',
 'pv_voucher_rebate_usd_campaign_voucher',
 'sv_voucher_rebate_usd_campaign_voucher',
 'item_rebate_usd_campaign_voucher',
 'prm_usd_pnl',
 'prm_usd_pnl_campaign_voucher',
 'total_rev_usd',
 'total_rev_usd_campaign_voucher',
]
df3[cols] = df3[cols].apply(pd.to_numeric, errors='coerce', axis=1)
df3['pc1_usd_pg'] = df3['rev_paid_ads_usd'] + df3['rev_pg_direct_revenue_usd'] + df3['rev_marketing_package'] - df3['cost_usd_pg']
df3['pc2_usd_pg'] = df3['pc1_usd_pg'] - df3['transaction_fee_usd']
df3['pc1_usd_pmo'] = df3['rev_pg_direct_revenue_usd_campaign_voucher'] + df3['rev_paid_ads_usd_campaign_voucher'] + df3['rev_marketing_package_campaign_voucher'] - df3['prm_usd_pg_campaign_voucher']
df3['pc2_usd_pmo'] = df3['pc1_usd_pmo'] - df3['transaction_fee_usd_campaign_voucher']

options3 = ['mall', 'platform','spp'] 
df_rs3 = df3[df3['project'].isin(options3)] 
df_rs3 = df_rs3[1:6000]
import gspread_dataframe as gd
gd.set_with_dataframe(output3, df_rs3)
# Out:
# <ipython-input-4-11b357d450eb>:128: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df3['pc1_usd_pg'] = df3['rev_paid_ads_usd'] + df3['rev_pg_direct_revenue_usd'] + df3['rev_marketing_package'] - df3['cost_usd_pg']
# <ipython-input-4-11b357d450eb>:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df3['pc2_usd_pg'] = df3['pc1_usd_pg'] - df3['transaction_fee_usd']
# ...
